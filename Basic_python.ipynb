# %%
n = 5
for i in range(n):
    for j in range(n):
        if i == 0 or i == n-1 or j == 0 or j == n-1:
            print('*', end=' ')
        else:
            print(' ', end=' ')
    print()  # move to next line
# Out:
# * * * * *
# *       *
# *       *
# *       *
# * * * * *

# %%
n=5
for i in range(1, n + 1):   
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
n=5
for i in range(1, n + 1):   
    print(' ' * (n - i) + '*' * (2 * i - 1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
n=5
for i in range(1,n+1):
    print(' '*(n-i)+'*'*(2*i-1))
for i in range(n-1,0,-1):
    print(' '*(n-i)+'*'*(2*i-1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
n=5
for i in range(1,n+1):
    print('* '* i)
for i in range(n-1,0,-1):
    print('* '* i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *
